# %%
#audiofile preprocessing
import scipy.signal as signal
import numpy as np
import librosa
import wave
import soundfile as sf
#spectrograms
import matplotlib.pyplot as plt
import numpy as np
import librosa
import librosa.display
import matplotlib
from tqdm import tqdm
import os

# %%
sampling_rate = 44100
cutoff_freq = 195
duration = 3
pitch_shift_value = -0.5
time_shift_value = 1.0

# %%
# Step 1: Denoising using a low pass filter
def apply_low_pass_filter(audio, sampling_rate, cutoff_freq):
    nyquist_freq = 0.5 * sampling_rate
    normalized_cutoff_freq = cutoff_freq / nyquist_freq
    b, a = signal.butter(4, normalized_cutoff_freq, btype='low', analog=False)
    denoised_audio = signal.lfilter(b, a, audio)
    return denoised_audio

# %%
# Downsampling audio
def downsample_audio(audio,original_sampling_rate,target_sampling_rate):
    resampled_audio = librosa.resample(audio, orig_sr=original_sampling_rate, target_sr=target_sampling_rate)
    return resampled_audio

# %%
# Split audio into fixed-length segments
def split_audio(audio, segment_length):
    num_segments = len(audio) // segment_length
    segments = [audio[i*segment_length:(i+1)*segment_length] for i in range(num_segments)]
    return segments

# %%
# Apply time shifting to audio
def apply_time_shift(audio, shift_factor):
    shifted_audio = np.roll(audio, shift_factor)
    return shifted_audio

# %%
# Apply pitch shifting to audio
def apply_pitch_shift(audio, sampling_rate, pitch_shift_steps):
    pitch_shifted_audio = librosa.effects.pitch_shift(audio, sr=sampling_rate, n_steps=pitch_shift_steps)
    return pitch_shifted_audio

# %%
import os
import librosa
# Set input and output folder paths
input_folder = '/Users/vaishnavikrovvidi/Desktop/pascalheartds/DatasetA/Atraining_artifact'
output_folder = '/Users/vaishnavikrovvidi/Desktop/pascalnew/augaudio/augartifact'

# Iterate over files in the input folder
for filename in os.listdir(input_folder):
    if filename.endswith(".wav"):
        # Load audio file
        audio_path = os.path.join(input_folder, filename)
        audio, sampling_rate = librosa.load(audio_path, sr=None)

        # Denoising, downsampling, splitting, time shifting, and pitch shifting
        # Denoising
        cutoff_frequency = 195
        denoised_audio = apply_low_pass_filter(audio, sampling_rate, cutoff_frequency)

        # Downsampling
        target_sampling_rate = sampling_rate // 10
        downsampled_audio = downsample_audio(denoised_audio, sampling_rate, target_sampling_rate)

        # Splitting audio
        segment_length = target_sampling_rate * 3
        segments = split_audio(downsampled_audio, segment_length)

        # Time shifting
        time_shift_factor = 1
        time_shifted_segments = [apply_time_shift(segment, time_shift_factor) for segment in segments]

        # Pitch shifting
        pitch_shift_steps = -0.5
        pitch_shifted_segments = [apply_pitch_shift(segment, target_sampling_rate, pitch_shift_steps) for segment in segments]

        # Saving augmented audio segments
        for i, segment in enumerate(pitch_shifted_segments):
            output_path = os.path.join(output_folder, f'segment_{i}_{filename}')
            sf.write(output_path, segment, target_sampling_rate)

# %%
import os
import librosa
# Set input and output folder paths
input_folder = '/Users/vaishnavikrovvidi/Desktop/pascalheartds/DatasetA/Atraining_normal'
output_folder = '/Users/vaishnavikrovvidi/Desktop/pascalnew/augaudio/augnorm'

# Iterate over files in the input folder
for filename in os.listdir(input_folder):
    if filename.endswith(".wav"):
        # Load audio file
        audio_path = os.path.join(input_folder, filename)
        audio, sampling_rate = librosa.load(audio_path, sr=None)

        # Denoising, downsampling, splitting, time shifting, and pitch shifting
        # Denoising
        cutoff_frequency = 195
        denoised_audio = apply_low_pass_filter(audio, sampling_rate, cutoff_frequency)

        # Downsampling
        target_sampling_rate = sampling_rate // 10
        downsampled_audio = downsample_audio(denoised_audio, sampling_rate, target_sampling_rate)

        # Splitting audio
        segment_length = target_sampling_rate * 3
        segments = split_audio(downsampled_audio, segment_length)

        # Time shifting
        time_shift_factor = 1
        time_shifted_segments = [apply_time_shift(segment, time_shift_factor) for segment in segments]

        # Pitch shifting
        pitch_shift_steps = -0.5
        pitch_shifted_segments = [apply_pitch_shift(segment, target_sampling_rate, pitch_shift_steps) for segment in segments]

        # Saving augmented audio segments
        for i, segment in enumerate(pitch_shifted_segments):
            output_path = os.path.join(output_folder, f'segment_{i}_{filename}')
            sf.write(output_path, segment, target_sampling_rate)

# %%
import os
import librosa
# Set input and output folder paths
input_folder = '/Users/vaishnavikrovvidi/Desktop/pascalheartds/DatasetA/Atraining_murmur'
output_folder = '/Users/vaishnavikrovvidi/Desktop/pascalnew/augaudio/augmurmur'

# Iterate over files in the input folder
for filename in os.listdir(input_folder):
    if filename.endswith(".wav"):
        # Load audio file
        audio_path = os.path.join(input_folder, filename)
        audio, sampling_rate = librosa.load(audio_path, sr=None)

        # Denoising, downsampling, splitting, time shifting, and pitch shifting
        # Denoising
        cutoff_frequency = 195
        denoised_audio = apply_low_pass_filter(audio, sampling_rate, cutoff_frequency)

        # Downsampling
        target_sampling_rate = sampling_rate // 10
        downsampled_audio = downsample_audio(denoised_audio, sampling_rate, target_sampling_rate)

        # Splitting audio
        segment_length = target_sampling_rate * 3
        segments = split_audio(downsampled_audio, segment_length)

        # Time shifting
        time_shift_factor = 1
        time_shifted_segments = [apply_time_shift(segment, time_shift_factor) for segment in segments]

        # Pitch shifting
        pitch_shift_steps = -0.5
        pitch_shifted_segments = [apply_pitch_shift(segment, target_sampling_rate, pitch_shift_steps) for segment in segments]

        # Saving augmented audio segments
        for i, segment in enumerate(pitch_shifted_segments):
            output_path = os.path.join(output_folder, f'segment_{i}_{filename}')
            sf.write(output_path, segment, target_sampling_rate)

# %%
import os
import librosa
# Set input and output folder paths
input_folder = '/Users/vaishnavikrovvidi/Desktop/pascalheartds/DatasetA/Atraining_extrahls'
output_folder = '/Users/vaishnavikrovvidi/Desktop/pascalnew/augaudio/augextrahls'

# Iterate over files in the input folder
for filename in os.listdir(input_folder):
    if filename.endswith(".wav"):
        # Load audio file
        audio_path = os.path.join(input_folder, filename)
        audio, sampling_rate = librosa.load(audio_path, sr=None)

        # Denoising, downsampling, splitting, time shifting, and pitch shifting
        # Denoising
        cutoff_frequency = 195
        denoised_audio = apply_low_pass_filter(audio, sampling_rate, cutoff_frequency)

        # Downsampling
        target_sampling_rate = sampling_rate // 10
        downsampled_audio = downsample_audio(denoised_audio, sampling_rate, target_sampling_rate)

        # Splitting audio
        segment_length = target_sampling_rate * 3
        segments = split_audio(downsampled_audio, segment_length)

        # Time shifting
        time_shift_factor = 1
        time_shifted_segments = [apply_time_shift(segment, time_shift_factor) for segment in segments]

        # Pitch shifting
        pitch_shift_steps = -0.5
        pitch_shifted_segments = [apply_pitch_shift(segment, target_sampling_rate, pitch_shift_steps) for segment in segments]

        # Saving augmented audio segments
        for i, segment in enumerate(pitch_shifted_segments):
            output_path = os.path.join(output_folder, f'segment_{i}_{filename}')
            sf.write(output_path, segment, target_sampling_rate)

# %%
import os
import librosa
# Set input and output folder paths
input_folder = '/Users/vaishnavikrovvidi/Desktop/pascalheartds/DatasetA/Atraining_artifact'
output_folder = '/Users/vaishnavikrovvidi/Desktop/pascalnew/everything'

# Iterate over files in the input folder
for filename in os.listdir(input_folder):
    if filename.endswith(".wav"):
        # Load audio file
        audio_path = os.path.join(input_folder, filename)
        audio, sampling_rate = librosa.load(audio_path, sr=None)

        # Denoising, downsampling, splitting, time shifting, and pitch shifting
        # Denoising
        cutoff_frequency = 195
        denoised_audio = apply_low_pass_filter(audio, sampling_rate, cutoff_frequency)

        # Downsampling
        target_sampling_rate = sampling_rate // 10
        downsampled_audio = downsample_audio(denoised_audio, sampling_rate, target_sampling_rate)

        # Splitting audio
        segment_length = target_sampling_rate * 3
        segments = split_audio(downsampled_audio, segment_length)

        # Time shifting
        time_shift_factor = 1
        time_shifted_segments = [apply_time_shift(segment, time_shift_factor) for segment in segments]

        # Pitch shifting
        pitch_shift_steps = -0.5
        pitch_shifted_segments = [apply_pitch_shift(segment, target_sampling_rate, pitch_shift_steps) for segment in segments]

        # Saving augmented audio segments
        for i, segment in enumerate(pitch_shifted_segments):
            output_path = os.path.join(output_folder, f'segment_{i}_{filename}')
            sf.write(output_path, segment, target_sampling_rate)

# %%
import os
import librosa
# Set input and output folder paths
input_folder = '/Users/vaishnavikrovvidi/Desktop/pascalheartds/DatasetA/Atraining_extrahls'
output_folder = '/Users/vaishnavikrovvidi/Desktop/pascalnew/everything'

# Iterate over files in the input folder
for filename in os.listdir(input_folder):
    if filename.endswith(".wav"):
        # Load audio file
        audio_path = os.path.join(input_folder, filename)
        audio, sampling_rate = librosa.load(audio_path, sr=None)

        # Denoising, downsampling, splitting, time shifting, and pitch shifting
        # Denoising
        cutoff_frequency = 195
        denoised_audio = apply_low_pass_filter(audio, sampling_rate, cutoff_frequency)

        # Downsampling
        target_sampling_rate = sampling_rate // 10
        downsampled_audio = downsample_audio(denoised_audio, sampling_rate, target_sampling_rate)

        # Splitting audio
        segment_length = target_sampling_rate * 3
        segments = split_audio(downsampled_audio, segment_length)

        # Time shifting
        time_shift_factor = 1
        time_shifted_segments = [apply_time_shift(segment, time_shift_factor) for segment in segments]

        # Pitch shifting
        pitch_shift_steps = -0.5
        pitch_shifted_segments = [apply_pitch_shift(segment, target_sampling_rate, pitch_shift_steps) for segment in segments]

        # Saving augmented audio segments
        for i, segment in enumerate(pitch_shifted_segments):
            output_path = os.path.join(output_folder, f'segment_{i}_{filename}')
            sf.write(output_path, segment, target_sampling_rate)

# %%
import os
import librosa
# Set input and output folder paths
input_folder = '/Users/vaishnavikrovvidi/Desktop/pascalheartds/DatasetA/Atraining_murmur'
output_folder = '/Users/vaishnavikrovvidi/Desktop/pascalnew/everything'

# Iterate over files in the input folder
for filename in os.listdir(input_folder):
    if filename.endswith(".wav"):
        # Load audio file
        audio_path = os.path.join(input_folder, filename)
        audio, sampling_rate = librosa.load(audio_path, sr=None)

        # Denoising, downsampling, splitting, time shifting, and pitch shifting
        # Denoising
        cutoff_frequency = 195
        denoised_audio = apply_low_pass_filter(audio, sampling_rate, cutoff_frequency)

        # Downsampling
        target_sampling_rate = sampling_rate // 10
        downsampled_audio = downsample_audio(denoised_audio, sampling_rate, target_sampling_rate)

        # Splitting audio
        segment_length = target_sampling_rate * 3
        segments = split_audio(downsampled_audio, segment_length)

        # Time shifting
        time_shift_factor = 1
        time_shifted_segments = [apply_time_shift(segment, time_shift_factor) for segment in segments]

        # Pitch shifting
        pitch_shift_steps = -0.5
        pitch_shifted_segments = [apply_pitch_shift(segment, target_sampling_rate, pitch_shift_steps) for segment in segments]

        # Saving augmented audio segments
        for i, segment in enumerate(pitch_shifted_segments):
            output_path = os.path.join(output_folder, f'segment_{i}_{filename}')
            sf.write(output_path, segment, target_sampling_rate)

# %%
import os
import librosa
# Set input and output folder paths
input_folder = '/Users/vaishnavikrovvidi/Desktop/pascalheartds/DatasetA/Atraining_normal'
output_folder = '/Users/vaishnavikrovvidi/Desktop/pascalnew/everything'

# Iterate over files in the input folder
for filename in os.listdir(input_folder):
    if filename.endswith(".wav"):
        # Load audio file
        audio_path = os.path.join(input_folder, filename)
        audio, sampling_rate = librosa.load(audio_path, sr=None)

        # Denoising, downsampling, splitting, time shifting, and pitch shifting
        # Denoising
        cutoff_frequency = 195
        denoised_audio = apply_low_pass_filter(audio, sampling_rate, cutoff_frequency)

        # Downsampling
        target_sampling_rate = sampling_rate // 10
        downsampled_audio = downsample_audio(denoised_audio, sampling_rate, target_sampling_rate)

        # Splitting audio
        segment_length = target_sampling_rate * 3
        segments = split_audio(downsampled_audio, segment_length)

        # Time shifting
        time_shift_factor = 1
        time_shifted_segments = [apply_time_shift(segment, time_shift_factor) for segment in segments]

        # Pitch shifting
        pitch_shift_steps = -0.5
        pitch_shifted_segments = [apply_pitch_shift(segment, target_sampling_rate, pitch_shift_steps) for segment in segments]

        # Saving augmented audio segments
        for i, segment in enumerate(pitch_shifted_segments):
            output_path = os.path.join(output_folder, f'segment_{i}_{filename}')
            sf.write(output_path, segment, target_sampling_rate)

# %%
def calculate_mel_spectrogram(audio_path, sampling_rate=44100//10, n_fft=2048, hop_length=512, n_mels=128):
    # Load audio file
    audio, _ = librosa.load(audio_path, sr=sampling_rate)

    # Apply Short-Time Fourier Transform (STFT)
    stft = librosa.stft(audio, n_fft=n_fft, hop_length=hop_length)

    # Convert magnitude STFT to mel-scale spectrogram
    mel_spec = librosa.feature.melspectrogram(S=np.abs(stft)**2, n_mels=n_mels)

    # Convert to decibel scale (logarithmic)
    log_mel_spec = librosa.power_to_db(mel_spec, ref=np.max)

    return log_mel_spec

# %%
def plot_spectrogram(spectrogram):
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(spectrogram, sr=sampling_rate, x_axis='time', y_axis='mel')
    plt.colorbar(format='%+2.0f dB')
    plt.title('Mel Spectrogram')
    plt.tight_layout()
    plt.show()

# %%
from PIL import Image
def save_spect(data, sr, filename):
    # Extract spectrogram
    spectrogram = librosa.feature.melspectrogram(y=data, sr=sr)

    # Convert to decibels
    spectrogram_db = librosa.power_to_db(spectrogram, ref=np.max)

    # Plot spectrogram
    plt.figure(figsize=(30,10))
    librosa.display.specshow(spectrogram_db, sr=sr)
    plt.savefig(("/Users/vaishnavikrovvidi/Desktop/pascalnew/everything/{}.png").format(filename), transparent=True)
    plt.close()
    img = Image.open(("/Users/vaishnavikrovvidi/Desktop/pascalnew/everything/{}.png").format(filename))
    img_resized = img.resize((128,128))

    # Crop the image to the bounding box

    #Save the resized image
    img_resized.save(("/Users/vaishnavikrovvidi/Desktop/pascalnew/everything/{}.png").format(filename))

# %%
import os

# Specify the folder path
folder_path = "/Users/vaishnavikrovvidi/Desktop/pascalnew/augaudio/augmurmur/"

# Loop through the files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".wav"):
        # Construct the full file path
        file_path = os.path.join(folder_path, filename)

        # Load the audio file
        data, sr = librosa.load(file_path)

        # Process and save the spectrogram
        save_spect(data, sr, os.path.splitext(filename)[0])

# %%
import os

# Specify the folder path
folder_path = "/Users/vaishnavikrovvidi/Desktop/pascalnew/augaudio/augnorm/"

# Loop through the files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".wav"):
        # Construct the full file path
        file_path = os.path.join(folder_path, filename)

        # Load the audio file
        data, sr = librosa.load(file_path)

        # Process and save the spectrogram
        save_spect(data, sr, os.path.splitext(filename)[0])

# %%
import os

# Specify the folder path
folder_path = "/Users/vaishnavikrovvidi/Desktop/pascalnew/augaudio/augextrahls/"

# Loop through the files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".wav"):
        # Construct the full file path
        file_path = os.path.join(folder_path, filename)

        # Load the audio file
        data, sr = librosa.load(file_path)

        # Process and save the spectrogram
        save_spect(data, sr, os.path.splitext(filename)[0])

# %%
import os

# Specify the folder path
folder_path = "/Users/vaishnavikrovvidi/Desktop/pascalnew/augaudio/augartifact/"

# Loop through the files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".wav"):
        # Construct the full file path
        file_path = os.path.join(folder_path, filename)

        # Load the audio file
        data, sr = librosa.load(file_path)

        # Process and save the spectrogram
        save_spect(data, sr, os.path.splitext(filename)[0])
